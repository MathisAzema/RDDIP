# %%
using Revise
using RDDIP
using Random
using Plots
using Gurobi
using Statistics
const GRB_ENV = Gurobi.Env()
optimizer=() -> Gurobi.Optimizer(GRB_ENV)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2658456
# Academic license - for non-commercial use only - expires 2026-04-28
# #11 (generic function with 1 method)

# %%
T = 5
graph=RDDIP.LinearGraph(T);

# %%
function subproblem_builder(instance::RDDIP.Instance, force::Float64, subproblem::Model, node::Int)
    # State variables
    H = [0.0, 50.0, 100.0, 150.0, 200.0]
    V = [0 for i in 1:5]
    V[5] = 1
    @variable(subproblem, volume[i in 1:5], Bin, RDDIP.State, initial_value = V[i])
    # @variable(subproblem, is_on, Bin, RDDIP.State, initial_value = 1)
    # Control variables
    @variables(subproblem, begin
        thermal_generation >= 0
        hydro_generation >= 0
        hydro_spill >= 0
    end)
    # Random variables
    @variable(subproblem, inflow)

    K=9
    Ω = [[k*200/K for k in 1:K] for t in 1:T]
    P = [[1/K for k in 1:K] for t in 1:T]
    Ω[1] = [50.0]
    P[1] = [1.0]
    RDDIP.parameterize(subproblem, Ω[node], P[node]) do ω
        return JuMP.fix(inflow, ω)
    end
    # Transition function and constraints
    @constraints(
        subproblem,
        begin
            sum(H[i] * volume[i].out for i in 1:5) == sum(H[i] * volume[i].in for i in 1:5) - hydro_generation - hydro_spill + inflow
            # thermal_generation <= 150 * is_on.out
            sum(volume[i].out for i in 1:5) == 1
            demand_constraint, hydro_generation + thermal_generation == 150
        end
    )
    # Stage-objective
    @stageobjective(subproblem, 50 * thermal_generation + 60 * hydro_spill)
    return subproblem
end

# %%
model = RDDIP.PolicyGraph(
    subproblem_builder,
    instance,
    0.0,
    graph;
    sense = :Min,
    lower_bound = 0.0,
    optimizer = optimizer,
)
# Out:
# UndefVarError: `subproblem_builder` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/RDDIP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X65sZmlsZQ==.jl:1

# %%
# println(model[1].subproblem)
model[2].noise_terms

# %%
# RDDIP.train(model; iteration_limit = 5, duality_handler = RDDIP.ContinuousConicDuality())
RDDIP.train(model; iteration_limit = 100, duality_handler = RDDIP.LagrangianDuality())
# RDDIP.train(model; iteration_limit = 100, duality_handler = RDDIP.StrengthenedConicDuality())

# %%
instance=RDDIP.parse_nc4("Data/T-Ramp/10_0_1_w.nc4",  optimizer, 24); instance.N
# Out:
# 10

# %%
res=RDDIP.bin_extensive_neutral_integer(instance; K=4, silent=false,  Tmax=2, force=0.0, S=1, batch=1, gap=0.001, timelimit=10);
# Out:
# Set parameter TimeLimit to value 10
# Set parameter Threads to value 1
# Set parameter MIPGap to value 0.001
# Set parameter MIPGap to value 0.001
# Set parameter Threads to value 1
# Set parameter TimeLimit to value 10
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 22 physical cores, 22 logical processors, using up to 1 threads
#
# Non-default parameters:
# TimeLimit  10
# MIPGap  0.001
# Threads  1
#
# Optimize a model with 3968 rows, 2557 columns and 15468 nonzeros
# Model fingerprint: 0xbfacd1b3
# Variable types: 827 continuous, 1730 integer (1730 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+03]
# Presolve removed 1095 rows and 435 columns
# Presolve time: 0.04s
# Presolved: 2873 rows, 2122 columns, 12246 nonzeros
# Variable types: 491 continuous, 1631 integer (1407 binary)
# Found heuristic solution: objective 3747427.7497
#
# Root relaxation: objective 1.844057e+06, 1159 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1844057.28    0  304 3747427.75 1844057.28  50.8%     -    0s
#      0     0 1858909.50    0  150 3747427.75 1858909.50  50.4%     -    0s
# H    0     0                    2128531.2335 1859052.73  12.7%     -    0s
# H    0     0                    1919340.3691 1859052.73  3.14%     -    0s
#      0     0 1859052.73    0  144 1919340.37 1859052.73  3.14%     -    0s
#      0     0 1859052.73    0  145 1919340.37 1859052.73  3.14%     -    0s
#      0     0 1860963.24    0  340 1919340.37 1860963.24  3.04%     -    0s
# H    0     0                    1871420.2962 1861019.35  0.56%     -    0s
#      0     0 1861151.70    0  314 1871420.30 1861151.70  0.55%     -    0s
#      0     0 1861188.89    0  334 1871420.30 1861188.89  0.55%     -    0s
#      0     0 1861194.06    0  334 1871420.30 1861194.06  0.55%     -    0s
#      0     0 1861449.82    0   86 1871420.30 1861449.82  0.53%     -    0s
# H    0     0                    1868652.3768 1861462.51  0.38%     -    0s
#      0     0 1861462.51    0   37 1868652.38 1861462.51  0.38%     -    0s
#      0     0 1861621.36    0   69 1868652.38 1861621.36  0.38%     -    0s
# H    0     0                    1868639.5921 1861623.08  0.38%     -    0s
#      0     0 1861623.08    0   68 1868639.59 1861623.08  0.38%     -    0s
#      0     0 1861630.43    0    3 1868639.59 1861630.43  0.38%     -    0s
# H    0     0                    1861630.4276 1861630.43  0.00%     -    0s
#      0     0 1861630.43    0    3 1861630.43 1861630.43  0.00%     -    0s
#
# Cutting planes:
#   Learned: 7
#   Gomory: 33
#   Cover: 72
#   Implied bound: 141
#   Clique: 53
#   MIR: 138
#   StrongCG: 3
#   Flow cover: 102
#   GUB cover: 22
#   Zero half: 3
#   Network: 1
#   RLT: 14
#   Relax-and-lift: 120
#
# Explored 1 nodes (2544 simplex iterations) in 0.34 seconds (0.36 work units)
# Thread count was 1 (of 22 available processors)
#
# Solution count 7: 1.86163e+06 1.86864e+06 1.86865e+06 ... 3.74743e+06
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 1.861630427636e+06, best bound 1.861630427636e+06, gap 0.0000%
#
# User-callback calls 918, time in user-callback 0.00 sec

# %%
RDDIP.bin_extensive_neutral(instance; silent=false,  force=1.0, S=20, batch=1, gap=0.001, timelimit=10);

# %%
resSP=RDDIP.benders_callback(instance, RDDIP.extended_BD_FH_OH, silent=false, force=1.0, S=20, batch=1, gap=0.1, timelimit=120);

# %%
T = 24
graph=RDDIP.LinearGraph(T);

# %%
force = 0.0
model = RDDIP.PolicyGraph(
    RDDIP.subproblem_builder_UC,
    instance,
    force,
    graph,
    sense = :Min,
    lower_bound = 0.0,
    optimizer = optimizer,
)
# Out:
# A policy graph with 24 nodes.
#  Node indices: 1, ..., 24

# %%
Random.seed!(12345)
# RDDIP.train(model; iteration_limit = 1, duality_handler = RDDIP.StrengthenedConicDuality())
RDDIP.train(model; iteration_limit = 100, duality_handler = RDDIP.LagrangianConicDuality())
# Out:
# -------------------------------------------------------------------
#          RDDIP.jl (c) Oscar Dowson and contributors, 2017-25
# -------------------------------------------------------------------
# problem
#   nodes           : 24
#   state variables : 183
#   scenarios       : 1.00000e+00
#   existing cuts   : false
# options
#   solver          : serial mode
#   risk measure    : RDDIP.Expectation()
#   sampling scheme : RDDIP.InSampleMonteCarlo
# subproblem structure
#   VariableRef                             :
", false), RDDIP.Log(5, 1.7670017503914167e6, 1.9020070033202635e6, 15.806237936019897, 1, 125, "S", false), RDDIP.Log(6, 1.7893589150087298e6, 1.9519938569464495e6, 16.763481855392456, 1, 150, "S", false), RDDIP.Log(7, 1.7896333627017764e6, 1.906018904031009e6, 17.803985834121704, 1, 175, "S", false), RDDIP.Log(8, 1.7896333627017764e6, 1.8729810106564856e6, 18.884989976882935, 1, 200, "S", false), RDDIP.Log(9, 1.7903234397332142e6, 2.1461227483735518e6, 19.792505979537964, 1, 225, "S", false), RDDIP.Log(10, 1.8103595401037594e6, 1.9091797463846745e6, 20.783087968826294, 1, 250, "S", false)  …  RDDIP.Log(91, 1.841255745352471e6, 1.8874554524177383e6, 110.7613799571991, 1, 2275, "S", false), RDDIP.Log(92, 1.8413115907406448e6, 1.8834787176468002e6, 112.13905787467957, 1, 2300, "S", false), RDDIP.Log(93, 1.8413115907406448e6, 1.8775803885335864e6, 113.38108777999878, 1, 2325, "S", false), RDDIP.Log(94, 1.8413193269920598e6, 1.8749255283791886e6, 114.631178855896, 1, 2350, "S", false), RDDIP.Log(95, 1.8414092629515743e6, 1.8758475835273822e6, 115.87766885757446, 1, 2375, "S", false), RDDIP.Log(96, 1.841503178298575e6, 1.8804058412338716e6, 117.08474278450012, 1, 2400, "S", false), RDDIP.Log(97, 1.841633500368559e6, 1.8798578149281908e6, 118.29554486274719, 1, 2425, "S", false), RDDIP.Log(98, 1.841633500368559e6, 1.876633904533382e6, 119.55065178871155, 1, 2450, "S", false), RDDIP.Log(99, 1.841633500368559e6, 1.9671121907414233e6, 120.64828777313232, 1, 2475, "S", false), RDDIP.Log(100, 1.841638348247073e6, 1.8711814348045997e6, 121.9446017742157, 1, 2500, "S", false)])

# %%
Random.seed!(12345)
RDDIP.train(model; iteration_limit = 100, duality_handler = RDDIP.StrengthenedConicDuality())
# RDDIP.train(model; iteration_limit = 1, duality_handler = RDDIP.LagrangianConicDuality())
# Out:
# -------------------------------------------------------------------
#          RDDIP.jl (c) Oscar Dowson and contributors, 2017-25
# -------------------------------------------------------------------
# problem
#   nodes           : 24
#   state variables : 183
#   scenarios       : 1.00000e+00
#   existing cuts   : false
# options
#   solver          : serial mode
#   risk measure    : RDDIP.Expectation()
#   sampling scheme : RDDIP.InSampleMonteCarlo
# subproblem structure
#   VariableRef                             : [432, 432]
#   AffExpr in MOI.EqualTo{Float64}         : [196, 196]
#   AffExpr in MOI.GreaterThan{Float64}     : [30, 213]
#   AffExpr in MOI.LessThan{Float64}        : [90, 273]
#   VariableRef in MOI.GreaterThan{Float64} : [33, 216]
#   VariableRef in MOI.LessThan{Float64}    : [183, 184]
#   VariableRef in MOI.ZeroOne              : [204, 204]
# numerical stability report
#   matrix range     [1e+00, 3e+02]
#   objective range  [1e+00, 3e+03]
#   bounds range     [1e+00, 1e+00]
#   rhs range        [1e+00, 1e+03]
# -------------------------------------------------------------------
#  iteration    simulation      bound        time (s)     solves  pid
# -------------------------------------------------------------------
#          1S  1.867524e+06  1.379667e+06  1.301451e+00        25   1
#          3S  1.913375e+06  1.794494e+06  2.495647e+00        75   1
#          5S  2.178056e+06  1.801908e+06  3.662228e+00       125   1
#          6S  1.865060e+06  1.808105e+06  4.851254e+00       150   1
#          8S  1.942138e+06  1.809150e+06  6.163815e+00       200   1
#         10S  1.914599e+06  1.810370e+06  7.512825e+00       250   1
@variable(model, x >= 0)
@variable(model, y >= 0)
@constraint(model, c1, x + y <= 10)
@constraint(model, c2, 2x - y >= 3)

cons = all_constraints(model; include_variable_in_set_constraints=true)
println(cons)
# Out:
# ConstraintRef[c2 : 2 x - y ≥ 3, c1 : x + y ≤ 10, x ≥ 0, y ≥ 0]

# %%
RDDIP.TrainingResults(:iteration_limit, RDDIP.Log[RDDIP.Log(1, 1.428402521661652e6, 1.8350314844269806e6, 3.765532970428467, 1, 140, "S", false), RDDIP.Log(2, 1.4869460945114475e6, 1.9150885666642494e6, 9.079401969909668, 1, 280, "S", false)])

# %%
res=RDDIP.train(model; iteration_limit = 2, print_level = 0, duality_handler = RDDIP.RDDIP.LagrangianConicDuality())

# %%
# string([res.log[i].simulation_value for i in 1:length(res.log)])
1.8574247832686587e6
# Out:
# 1.8574247832686587e6

# %%
println(model[23].subproblem)

# %%
println(model[23].subproblem)
# mod = model[23].subproblem
# optimize!(mod)

# %%
node = model[23]
for (key, state) in node.states
    # println((key, value(state.in), JuMP.is_integer(state.in), JuMP.upper_bound(state.in)))
    println((key, state.out, JuMP.is_binary(state.out), node.incoming_state_bounds[key]))
    # println((key, value(state.in), JuMP.is_integer(state.in)))
    # println(JuMP.upper_bound(state.in))
end
JuMP.upper_bound(collect(values(node.states))[1].in)
# collect(values(node.states))[1].in

# %%
println(model[1].subproblem)

# %%
1.806476027737761e6, 1.8289582420327545e6

# %%
mod = JuMP.Model(optimizer)
@variable(mod, x, Bin)
@variable(mod, y )
@objective(mod, Max, x)
# JuMP.optimize!(mod)
# JuMP.termination_status(mod)
undo_relax = JuMP.relax_integrality(mod)
println(mod)
# undo_relax()
# JuMP.upper_bound(x)
using Dualization
md=dualize(mod)
println(md)
# Out:
# Max x
# Subject to
#  x ≥ 0
#  x ≤ 1
#
# Min -_[1]
# Subject to
#  0 = 0
#  -_[1] ≥ 1
#  _[1] ≤ 0

# %%
using Dualization
mod = JuMP.Model(optimizer)
@variable(mod, x)
@variable(mod, y)
@constraint(mod, s,x + y <= 10)
@objective(mod, Min, x)

new_model, reference_map = copy_model(mod)
@constraint(new_model, fix_x, reference_map[x] == 1.0)
println(new_model)

md=dualize(new_model; dual_names = DualNames("dual_var_", "dual_con_"))
# println(md)
# reference_map[s]
hexpr = JuMP.objective_function(md)
println(md)
@variable(md, z)
@constraint(md, z <= hexpr)
@objective(md, Max, z)
println(md)
md[Symbol("dual_var_", "s")]
# Out:
# Min x
# Subject to
#  fix_x : x = 1
#  s : x + y ≤ 10
#
# Max 10 dual_var_s + dual_var_fix_x
# Subject to
#  dual_con_x : dual_var_fix_x + dual_var_s = 1
#  dual_con_y : dual_var_s = 0
#  dual_var_s ≤ 0
#
# Max z
# Subject to
#  dual_con_x : dual_var_fix_x + dual_var_s = 1
#  dual_con_y : dual_var_s = 0
#  -dual_var_fix_x - 10 dual_var_s + z ≤ 0
#  dual_var_s ≤ 0
# dual_var_s

# %%
using Suppressor, Dualization
node = model[24]
mod = node.subproblem
undo_relax = JuMP.relax_integrality(mod)
new_model, reference_map = @suppress copy_model(mod)
undo_relax()
copy_state_out = Dict()
copy_state_in = Dict()
copy_uncertainty = Dict()
for (name,state) in node.states
    copy_state_out[name] = JuMP.variable_by_name(new_model, string(name,"_out"))
    copy_state_in[name] = JuMP.variable_by_name(new_model, string(name,"_in"))
end
for (name,uncertainty) in node.uncertainties
    # println(name, uncertainty)
    copy_uncertainty[name] = JuMP.variable_by_name(new_model, string(name))
end
@constraint(new_model, fix_out[name in keys(copy_state_out)], copy_state_out[name] == 1.0)
@constraint(new_model, fix_in[name in keys(copy_state_in)], copy_state_in[name] == 0.0)
@constraint(new_model, fix_uncertainty[name in keys(copy_uncertainty)], copy_uncertainty[name] == 0.0)
println(new_model)
md=dualize(new_model; consider_constrained_variables=false, dual_names = DualNames("dual_var_", "dual_con_"))
hexpr = JuMP.objective_function(md)
@variable(md, θ)
@constraint(md, θ <= hexpr)
@objective(md, Max, θ)
println(md)
dual_variables_states_out = Dict(name => md[Symbol("dual_var_fix_out[$name]")] for name in keys(copy_state_out))
dual_variables_states_in = Dict(name => md[Symbol("dual_var_fix_in[$name]")] for name in keys(copy_state_in))
dual_variables_uncertainty = Dict(name => md[Symbol("dual_var_fix_uncertainty[$name]")] for name in keys(copy_uncertainty))
# Out:
# Min 43.169962 power_real[1] + 300 power_shedding[1] + 300 power_curtailement[1] + 1337.77358 is_on[1]_out + 172.862432 start_up[1] + _[23]
# Subject to
#  32 power_integer[1,1]_out + 60.66666666666667 power_integer[1,2]_out + 89.33333333333334 power_integer[1,3]_out + 118 power_integer[1,4]_out + power_dev[1] - power_real[1] = 0
#  32 power_integer[1,1]_out + 60.66666666666667 power_integer[1,2]_out + 89.33333333333334 power_integer[1,3]_out + 118 power_integer[1,4]_out - power[1] = 0
#  32 power_integer[1,1]_in + 60.66666666666667 power_integer[1,2]_in + 89.33333333333334 power_integer[1,3]_in + 118 power_integer[1,4]_in - power_prev[1] = 0
#  -is_on[1]_out + power_integer[1,1]_out + power_integer[1,2]_out + power_integer[1,3]_out + power_integer[1,4]_out = 0
#  -is_on[1]_in + power_integer[1,1]_in + power_integer[1,2]_in + power_integer[1,3]_in + power_integer[1,4]_in = 0
#  -is_on[1]_in + is_on[1]_out - start_up[1] + start_down[1] = 0
#  uncertainty[1] + uncertainty[2] = 1
#  error_forecast[1] + uncertainty[1] + 0.5 uncertainty[2] = 0
#  power_real[1] + power_shedding[1] - power_curtailement[1] - 50.71290672000001 error_forecast[1] = 1034.95728
#  fix_out[is_on[1]] : is_on[1]_out = 1
#  fix_out[power_integer[1,1]] : power_integer[1,1]_out = 1
#  fix_out[power_integer[1,3]] : power_integer[1,3]_out = 1
#  fix_out[power_integer[1,2]] : power_integer[1,2]_out = 1
#  fix_out[power_integer[1,4]] : power_integer[1,4]_out = 1
#  fix_in[is_on[1]] : is_on[1]_in = 0
#  fix_in[power_integer[1,1]] : power_integer[1,1]_in = 0
#  fix_in[power_integer[1,3]] : power_integer[1,3]_in = 0
#  fix_in[power_integer[1,2]] : power_integer[1,2]_in = 0
#  fix_in[power_integer[1,4]] : power_integer[1,4]_in = 0
#  fix_uncertainty[uncertainty[1]] : uncertainty[1] = 0
#  fix_uncertainty[uncertainty[2]] : uncertainty[2] = 0
#  14.333333333333334 is_on[1]_out + power_dev[1] ≥ 0
#  -32 is_on[1]_out + power[1] ≥ 0
#  -32 is_on[1]_out + power_real[1] ≥ 0
#  is_on[1]_in ≥ 0
#  power_integer[1,1]_in ≥ 0
#  power_integer[1,3]_in ≥ 0
#  power_integer[1,2]_in ≥ 0
#  power_integer[1,4]_in ≥ 0
#  -14.333333333333334 is_on[1]_out + power_dev[1] ≤ 0
#  -is_on[1]_out + start_up[1] ≤ 0
#  is_on[1]_out + start_down[1] ≤ 1
#  -118 is_on[1]_out + power[1] ≤ 0
#  -118 is_on[1]_out + power_real[1] ≤ 0
#  32 is_on[1]_in - 74.00380799999999 is_on[1]_out + 42.003808 start_up[1] + power_real[1] - power_prev[1] ≤ 0
#  -64.599073 is_on[1]_in + 32 is_on[1]_out + 32.599073 start_down[1] - power_real[1] + power_prev[1] ≤ 0
#  is_on[1]_in ≤ 1
#  power_integer[1,1]_in ≤ 1
#  power_integer[1,3]_in ≤ 1
#  power_integer[1,2]_in ≤ 1
#  power_integer[1,4]_in ≤ 1
#  is_on[1]_out ≥ 0
#  start_up[1] ≥ 0
#  start_down[1] ≥ 0
#  power_integer[1,1]_out ≥ 0
#  power_integer[1,2]_out ≥ 0
#  power_integer[1,3]_out ≥ 0
#  power_integer[1,4]_out ≥ 0
#  power[1] ≥ 0
#  power_real[1] ≥ 0
#  power_prev[1] ≥ 0
#  power_shedding[1] ≥ 0
#  power_curtailement[1] ≥ 0
#  uncertainty[1] ≥ 0
#  uncertainty[2] ≥ 0
#  _[23] ≥ 0
#  is_on[1]_out ≤ 1
#  start_up[1] ≤ 1
#  start_down[1] ≤ 1
#  power_integer[1,1]_out ≤ 1
#  power_integer[1,2]_out ≤ 1
#  power_integer[1,3]_out ≤ 1
#  power_integer[1,4]_out ≤ 1
#  uncertainty[1] ≤ 1
#  uncertainty[2] ≤ 1
#  _[23] ≤ 0
#
# Max θ
# Subject to
#  dual_con_is_on[1]_in : -_[5] - _[6] + dual_var_fix_in[is_on[1]] + _[25] + 32 _[35] - 64.599073 _[36] + _[37] = 0
#  dual_con_is_on[1]_out : -_[4] + _[6] + dual_var_fix_out[is_on[1]] + 14.333333333333334 _[22] - 32 _[23] - 32 _[24] - 14.333333333333334 _[30] - _[31] + _[32] - 118 _[33] - 118 _[34] - 74.00380799999999 _[35] + 32 _[36] + _[42] + _[57] = 1337.77358
#  dual_con_start_up[1] : -_[6] + _[31] + 42.003808 _[35] + _[43] + _[58] = 172.862432
#  dual_con_start_down[1] : _[6] + _[32] + 32.599073 _[36] + _[44] + _[59] = 0
#  dual_con_power_integer[1,1]_in : 32 _[3] + _[5] + dual_var_fix_in[power_integer[1,1]] + _[26] + _[38] = 0
#  dual_con_power_integer[1,1]_out : 32 _[1] + 32 _[2] + _[4] + dual_var_fix_out[power_integer[1,1]] + _[45] + _[60] = 0
#  dual_con_power_integer[1,2]_in : 60.66666666666667 _[3] + _[5] + dual_var_fix_in[power_integer[1,2]] + _[28] + _[40] = 0
#  dual_con_power_integer[1,2]_out : 60.66666666666667 _[1] + 60.66666666666667 _[2] + _[4] + dual_var_fix_out[power_integer[1,2]] + _[46] + _[61] = 0
#  dual_con_power_integer[1,3]_in : 89.33333333333334 _[3] + _[5] + dual_var_fix_in[power_integer[1,3]] + _[27] + _[39] = 0
#  dual_con_power_integer[1,3]_out : 89.33333333333334 _[1] + 89.33333333333334 _[2] + _[4] + dual_var_fix_out[power_integer[1,3]] + _[47] + _[62] = 0
#  dual_con_power_integer[1,4]_in : 118 _[3] + _[5] + dual_var_fix_in[power_integer[1,4]] + _[29] + _[41] = 0
#  dual_con_power_integer[1,4]_out : 118 _[1] + 118 _[2] + _[4] + dual_var_fix_out[power_integer[1,4]] + _[48] + _[63] = 0
#  dual_con_power_dev[1] : _[1] + _[22] + _[30] = 0
#  dual_con_power[1] : -_[2] + _[23] + _[33] + _[49] = 0
#  dual_con_power_real[1] : -_[1] + _[9] + _[24] + _[34] + _[35] - _[36] + _[50] = 43.169962
#  dual_con_power_prev[1] : -_[3] - _[35] + _[36] + _[51] = 0
#  dual_con_power_shedding[1] : _[9] + _[52] = 300
#  dual_con_power_curtailement[1] : -_[9] + _[53] = 300
#  dual_con_θ[1] : 0 = 0
#  dual_con_error_forecast[1] : _[8] - 50.71290672000001 _[9] = 0
#  dual_con_uncertainty[1] : _[7] + _[8] + dual_var_fix_uncertainty[uncertainty[1]] + _[54] + _[64] = 0
#  dual_con_uncertainty[2] : _[7] + 0.5 _[8] + dual_var_fix_uncertainty[uncertainty[2]] + _[55] + _[65] = 0
#  dual_con_ : _[56] + _[66] = 1
#  -_[7] - 1034.95728 _[9] - dual_var_fix_out[is_on[1]] - dual_var_fix_out[power_integer[1,1]] - dual_var_fix_out[power_integer[1,3]] - dual_var_fix_out[power_integer[1,2]] - dual_var_fix_out[power_integer[1,4]] - _[32] - _[37] - _[38] - _[39] - _[40] - _[41] - _[57] - _[58] - _[59] - _[60] - _[61] - _[62] - _[63] - _[64] - _[65] + θ ≤ 0
#  _[22] ≥ 0
#  _[23] ≥ 0
#  _[24] ≥ 0
#  _[25] ≥ 0
#  _[26] ≥ 0
#  _[27] ≥ 0
#  _[28] ≥ 0
#  _[29] ≥ 0
#  _[42] ≥ 0
#  _[43] ≥ 0
#  _[44] ≥ 0
#  _[45] ≥ 0
#  _[46] ≥ 0
#  _[47] ≥ 0
#  _[48] ≥ 0
#  _[49] ≥ 0
#  _[50] ≥ 0
#  _[51] ≥ 0
#  _[52] ≥ 0
#  _[53] ≥ 0
#  _[54] ≥ 0
#  _[55] ≥ 0
#  _[56] ≥ 0
#  _[30] ≤ 0
#  _[31] ≤ 0
#  _[32] ≤ 0
#  _[33] ≤ 0
#  _[34] ≤ 0
#  _[35] ≤ 0
#  _[36] ≤ 0
#  _[37] ≤ 0
#  _[38] ≤ 0
#  _[39] ≤ 0
#  _[40] ≤ 0
#  _[41] ≤ 0
#  _[57] ≤ 0
#  _[58] ≤ 0
#  _[59] ≤ 0
#  _[60] ≤ 0
#  _[61] ≤ 0
#  _[62] ≤ 0
#  _[63] ≤ 0
#  _[64] ≤ 0
#  _[65] ≤ 0
#  _[66] ≤ 0
# Dict{Symbol, VariableRef} with 2 entries:
#   Symbol("uncertainty[1]") => dual_var_fix_uncertainty[uncertainty[1]]
#   Symbol("uncertainty[2]") => dual_var_fix_uncertainty[uncertainty[2]]

# %%
lagrangian = model[24].lagrangian
cstr = lagrangian.upper_constraint
var = dual_variables_states_out[Symbol("power_integer[1,1]")]
set_normalized_coefficient(cstr, var, -1)
set_normalized_rhs(cstr, 3)
cstr
# Out:
# -_[7] - 1034.95728 _[9] - _[32] - _[37] - _[38] - _[39] - _[40] - _[41] - _[62] - _[63] - _[64] - _[65] - _[66] - _[67] - _[68] - _[69] - _[70] - _[71] - _[72] - _[73] - _[74] - _[75] + theta_24 - dual_var_fix_out[power_integer[1,1]] ≤ 3

# %%
using JuMP, Dualization
model = Model()
@variable(model, x)
@variable(model, y)
@variable(model, z)
@constraint(model, soccon, [x; y; z] in SecondOrderCone())
@constraint(model, eqcon, x == 1)
@objective(model, Min, y + z)
dual_model = dualize(model; consider_constrained_variables=false, dual_names = DualNames("", ""))
println(dual_model)
# Out:
# Max eqcon
# Subject to
#  x : eqcon + soccon_1 = 0
#  y : soccon_2 = 1
#  z : soccon_3 = 1
#  [soccon_1, soccon_2, soccon_3] ∈ MathOptInterface.SecondOrderCone(3)

# %%
new_model
# Out:
# A JuMP Model
# ├ solver: none
# ├ objective_sense: MIN_SENSE
# │ └ objective_function_type: AffExpr
# ├ num_variables: 23
# ├ num_constraints: 68
# │ ├ AffExpr in MOI.EqualTo{Float64}: 21
# │ ├ AffExpr in MOI.GreaterThan{Float64}: 8
# │ ├ AffExpr in MOI.LessThan{Float64}: 12
# │ ├ VariableRef in MOI.EqualTo{Float64}: 7
# │ ├ VariableRef in MOI.GreaterThan{Float64}: 13
# │ └ VariableRef in MOI.LessThan{Float64}: 7
# └ Names registered in the model
#   └ :error_forecast, :fix_in, :fix_out, :fix_uncertainty, :flow, :power, :power_curtailement, :power_dev, :power_prev, :power_real, :power_shedding, :start_down, :start_up, :θ

# %%
dualize(new_model)
# Out:
# A JuMP Model
# ├ solver: none
# ├ objective_sense: MAX_SENSE
# │ └ objective_function_type: AffExpr
# ├ num_variables: 51
# ├ num_constraints: 46
# │ ├ AffExpr in MOI.EqualTo{Float64}: 6
# │ ├ AffExpr in MOI.GreaterThan{Float64}: 13
# │ ├ VariableRef in MOI.GreaterThan{Float64}: 8
# │ └ VariableRef in MOI.LessThan{Float64}: 19
# └ Names registered in the model: none

# %%
using JuMP, Dualization, LinearAlgebra

# Ton modèle original
model = Model()
@variable(model, x1 >= 0)
@variable(model, x2)
@constraint(model, x2 == 4)
@constraint(model, 2x1 - x2 >= 1)
@constraint(model, x1 + x2 <= 3)
@objective(model, Min, x1 + 2x2)

# --- Étape 1 : standardiser ---
# Dualization.jl fournit un utilitaire pour cela :
# standard_model = Dualization.standard_form(model)

# --- Étape 2 : dualiser ---
dual_model = dualize(model)

println("Nb variables primal standardisé: ", num_variables(model))
# println("Nb contraintes dual: ", num_constraints(dual_model))
println(dual_model)
# Out:
# Nb variables primal standardisé: 2
# Max _[2] + 3 _[3] + 4 _[1]
# Subject to
#  _[1] - _[2] + _[3] = 2
#  -2 _[2] - _[3] ≥ -1
#  _[2] ≥ 0
#  _[3] ≤ 0

# %%
println(model[2].lagrangian.model)
# Out:
# Max theta_2
# Subject to
#  dual_con_power_dev[1] : _[1] + _[22] + _[30] = 0
#  dual_con_θ[1] : 0 = 0
#  dual_con_error_forecast[1] : _[8] - 44.209449242 _[9] = 0
#  dual_con_uncertainty[2] : _[7] + 0.5 _[8] + dual_var_fix_uncertainty[uncertainty[2]] + _[42] = 0
#  dual_con_start_down[1] : -_[6] - _[32] - 32.599073 _[36] - _[46] ≥ 0
#  dual_con_start_up[1] : _[6] - _[31] - 42.003808 _[35] - _[45] ≥ -172.862432
#  dual_con_power_integer[1,4]_out : -118 _[1] - 118 _[2] - _[4] - dual_var_fix_out[power_integer[1,4]] - _[54] ≥ 0
#  dual_con_power[1] : _[2] - _[23] - _[33] ≥ 0
#  dual_con_ : 0 ≥ -1
#  dual_con_power_integer[1,3]_in : -89.33333333333334 _[3] - _[5] - dual_var_fix_in[power_integer[1,3]] - _[27] - _[39] - _[51] ≥ 0
#  dual_con_power_integer[1,1]_out : -32 _[1] - 32 _[2] - _[4] - dual_var_fix_out[power_integer[1,1]] - _[48] ≥ 0
#  dual_con_power_curtailement[1] : _[9] ≥ -300
#  dual_con_power_integer[1,2]_out : -60.66666666666667 _[1] - 60.66666666666667 _[2] - _[4] - dual_var_fix_out[power_integer[1,2]] - _[50] ≥ 0
#  dual_con_power_integer[1,2]_in : -60.66666666666667 _[3] - _[5] - dual_var_fix_in[power_integer[1,2]] - _[28] - _[40] - _[49] ≥ 0
#  dual_con_power_prev[1] : _[3] + _[35] - _[36] ≥ 0
#  dual_con_is_on[1]_in : _[5] + _[6] - dual_var_fix_in[is_on[1]] - _[25] - 32 _[35] + 64.599073 _[36] - _[37] - _[43] ≥ 0
#  dual_con_power_shedding[1] : -_[9] ≥ -300
#  dual_con_is_on[1]_out : _[4] - _[6] - dual_var_fix_out[is_on[1]] - 14.333333333333334 _[22] + 32 _[23] + 32 _[24] + 14.333333333333334 _[30] + _[31] - _[32] + 118 _[33] + 118 _[34] + 74.00380799999999 _[35] - 32 _[36] - _[44] ≥ -1337.77358
#  dual_con_power_integer[1,1]_in : -32 _[3] - _[5] - dual_var_fix_in[power_integer[1,1]] - _[26] - _[38] - _[47] ≥ 0
#  dual_con_power_integer[1,4]_in : -118 _[3] - _[5] - dual_var_fix_in[power_integer[1,4]] - _[29] - _[41] - _[53] ≥ 0
#  dual_con_power_real[1] : _[1] - _[9] - _[24] - _[34] - _[35] + _[36] ≥ -43.169962
#  dual_con_power_integer[1,3]_out : -89.33333333333334 _[1] - 89.33333333333334 _[2] - _[4] - dual_var_fix_out[power_integer[1,3]] - _[52] ≥ 0
#  -_[7] - 902.233658 _[9] - _[32] - _[37] - _[38] - _[39] - _[40] - _[41] - _[42] - _[43] - _[44] - _[45] - _[46] - _[47] - _[48] - _[49] - _[50] - _[51] - _[52] - _[53] - _[54] + theta_2 ≤ 0
#  _[22] ≥ 0
#  _[23] ≥ 0
#  _[24] ≥ 0
#  _[25] ≥ 0
#  _[26] ≥ 0
#  _[27] ≥ 0
#  _[28] ≥ 0
#  _[29] ≥ 0
#  _[30] ≤ 0
#  _[31] ≤ 0
#  _[32] ≤ 0
#  _[33] ≤ 0
#  _[34] ≤ 0
#  _[35] ≤ 0
#  _[36] ≤ 0
#  _[37] ≤ 0
#  _[38] ≤ 0
#  _[39] ≤ 0
#  _[40] ≤ 0
#  _[41] ≤ 0
#  _[43] ≤ 0
#  _[44] ≤ 0
#  _[45] ≤ 0
#  _[46] ≤ 0
#  _[47] ≤ 0
#  _[48] ≤ 0
#  _[49] ≤ 0
#  _[50] ≤ 0
#  _[51] ≤ 0
#  _[52] ≤ 0
#  _[53] ≤ 0
#  _[54] ≤ 0

# %%
mod = model[2].lagrangian.model
# set_optimizer(mod, optimizer)
set_optimizer_attribute(mod, "Presolve", 0)
println(mod)
unset_silent(mod)  # Remet les sorties du solveur
optimize!(mod)
println("Termination status: ", JuMP.termination_status(mod))
println("Primal status:     ", JuMP.primal_status(mod))
Dict(i =>value.(var) for (i, var) in model[2].lagrangian.dual_variables)
for (i, var) in model[2].lagrangian.dual_variables
    if abs(value(var)) > 1e-6
        println("Variable ", i, " has value ", value(var))
    end
end
println(value(model[2].lagrangian.theta))

# %%
using XLSX

# Ouvre le fichier Excel
xlsx = XLSX.readxlsx("results_1000.xlsx")
# Out:
# XLSXFile("results_1000.xlsx") containing 1 Worksheet
#             sheetname size          range
# -------------------------------------------------
#               results 5x4           A1:D5

# %%
Lower_bound = Dict()
computation_time = Dict()
for i in 2:5
    name = xlsx["results"]["A$i"]
    A = xlsx["results"]["B$i"]
    B = parse.(Float64, split(strip(A, ['[', ']']), ","))
    C = xlsx["results"]["D$i"]
    Lower_bound[name] = B
    computation_time[name] = parse.(Float64, split(strip(C, ['[', ']']), ","))
end

# %%
K=12
N=1000
using Plots
p = plot(title="SDDIP 1 scenario",
     xlabel="Iteration",
     ylabel="LB",
    #  lw=2,                # largeur des lignes
     legend=:bottomright,
    titlefontsize=24, 
    guidefontsize=20, 
    tickfontsize=20, 
    legendfontsize=20,
    size=(800, 600),
    linewidth=3, )     # position de la légende

for (nom, valeurs) in Lower_bound
    plot!(1:length(valeurs[K:end]), valeurs[K:end], label=nom, linewidth=3)
end
plot!([N for N in 1:N-K], [1827475 for N in 1:N-K], color=:black, linewidth=3, label="UB")

display(p)
savefig("SDDIP1.png")
# Out:
# "/home/mathis/Documents/RDDIP/SDDIP1.png"

# %%
K=12
N=1000
using Plots
p = plot(title="SDDIP 1 scenario",
     xlabel="Iteration",
     ylabel="LB",
    #  lw=2,                # largeur des lignes
     legend=:bottomright,
    titlefontsize=24, 
    guidefontsize=20, 
    tickfontsize=20, 
    legendfontsize=20,
    size=(800, 600),
    linewidth=3, )     # position de la légende

for (nom, valeurs) in Lower_bound
    # plot!(1:length(valeurs[K:end]), valeurs[K:end], label=nom, linewidth=3)
    plot!(computation_time[nom][K:end], valeurs[K:end], label=nom, linewidth=3)
end
plot!([N for N in 1:2500-K], [1827475 for N in 1:2500-K], color=:black, linewidth=3, label="UB")

display(p)
savefig("SDDIP1time.png")
